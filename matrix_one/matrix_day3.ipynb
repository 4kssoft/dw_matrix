# %%
cd /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
cd matrix_one

# %%
# !echo "data" > .gitignore
# !git add .gitignore

# %%
# !ls

# %%
# !pip install datadotworld
# !pip install datadotworld[pandas]

# %%
# !dw configure

# %%
import pandas as pd
import numpy as np

import datadotworld as dw

# %%
data = dw.load_dataset('datafiniti/mens-shoe-prices')

# %%
df = data.dataframes['7004_1']
df.head()

# %%
data_womens = dw.load_dataset('datafiniti/womens-shoe-prices')

# %%
dfw = data_womens.dataframes['7003_1']
dfw.head()

# %%
df.columns

# %%
df.prices_currency.value_counts()

# %%
dfw.prices_currency.value_counts()

# %%
df_usd = df[df.prices_currency == 'USD'].copy()
df_usd.shape

# %%
dfw_usd = dfw[dfw.prices_currency == 'USD'].copy()
dfw_usd.shape

# %%
df_usd.prices_amountmin = df_usd.prices_amountmin.astype(np.float)

# %%
dfw_usd.prices_amountmin = dfw_usd.prices_amountmin.astype(np.float)

# %%
df_usd.prices_amountmin.hist();

# %%
dfw_usd.prices_amountmin.hist();

# %%
filter_max = np.percentile(df_usd.prices_amountmin, 99)
filter_max

# %%
filter_womens_max = np.percentile(dfw_usd.prices_amountmin, 99)
filter_womens_max

# %%
df_usd_filter = df_usd[df_usd.prices_amountmin < filter_max]

# %%
dfw_usd_filter = dfw_usd[dfw_usd.prices_amountmin < filter_womens_max]

# %%
df_usd_filter.prices_amountmin.hist(bins=100);

# %%
dfw_usd_filter.prices_amountmin.hist(bins=100, tit);
